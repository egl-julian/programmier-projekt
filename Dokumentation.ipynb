# %% [markdown]
# # Dokumentation für das Programmierprojekt "Bestimmung der mechanischen Eigenschaften eines Balkenquerschnitts aus Bilddaten"
# ---
# ## Ablauf
# 1. Kalibrierung der Kamera mit hilfe von Schachbrettmustern durch die Funktion "setup" in calibration
# 2. Einlesen eines Dateinamens der zu verarbeitenden Bilddatei
# 3. Entfernen der Bildkrümmung durch "undistortion"
# 4. Finden der Querschnittskontur durch "contour"
# 5. Berechnung der gesuchten größen des Querschnitts mit "corssSection"
#
# ## Übersicht der Funktionen
# ---
# ### setup-Funktion
#
# Aufruf durch:

# %%
import calibration
calibration.setup()

# %% [markdown]
# Die Setup-Funktion erkennt anhand von verschiedenen Bildern eines Schachbrettmusters mit 9x6 Rechtecken die Verzerrung der Kamera und gibt diese zurück. Die Bilder des Musters müssen mit dem Namen kalib*.jpg abgespeichert sein, wobei * ein Platzhalter für eine mögliche Nummerierung der einzelnen Bilder ist.

# %% [markdown]
# ---
# ## undistortion-Funktion
# Aufruf durch:

# %%
import undistortion as undis
undis.undistortion()

# %% [markdown]
# Die Funktion benötigt zwei Rückgabewerte der setup-Funktion mtx und dst. Außerdem wird der Name des zu verarbeitenden Bildes übergen. Die Funktion liefert keinen Rückgabewert, statt dessen wird das kalibrierte Bild mit dem Namen "kalibriert.png" abgespeichert.
