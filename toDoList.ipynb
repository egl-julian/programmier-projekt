# %% [markdown]
# # To-Do-Liste Programmierprojekt
# - Debugging Code mit if __name__ == '__main__' in einzelne Module einbinden, z.B. Tests für die Kamerakalibreirung
# - Länge in Pixeln zur Umrechnung kann mit Vektoren berechnet werden; der Betrag der subtrahieren Vektoren liefert die länge in Pixeln, diese kann dann in mm umgerechnet    werden
